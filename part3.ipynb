# %%
file4=open("rida_docids.txt").read()
file5=file4.split("\n")
dictionary_3={}
dictionary4={}
for i in range(len(file5)-1):
        var4=file5[i].split('_')
        dictionary_3[var4[1]]=var4[0]
file6=open("rida_doc_index.txt").read()
file7=file6.split("\n")
for i in range(len(file7)-1):
    var5=file7[i].split('\t')
    var6=var5[1].split(':')
    for j in range (len(var6)-1):    
        var7=var6[j].split(',')
        if dictionary4.get(int(var5[0])) != " ":
            L =dictionary4.get(int(var5[0]))
        else:
            L=[]
        L.append((var7[1],var7[0]))
        dictionary4[int(var5[0])] = L

# %%
def read_func_2(doc):
    
    var1=dictionary_3.get(doc)
    
    b=dictionary4.get(int(var1))
    total_len=len(b)
    arr=[]
    for p in dictionary4.get(int(var1)):
        arr.append(p[0])
    arr=[*set(arr)]
    length=len(arr)
    print("Listing for document:"+str(doc)+"\n"+"DOCID:", str(var1)+"\n"+"Distinct terms:",str(length)+"\n"+"Total terms:",str(total_len))

# %%
read_func_2("3.txt")
# Out:
# Listing for document:3.txt
# DOCID: 4127
# Distinct terms: 110
# Total terms: 176

# %%
file2=open("term_info.txt").read()
file3=file2.split("\n")
dictionary_2={}
lis=[]
for i in range(len(file3)-1):
    var2=file3[i].split("\t")
    for f in range (len(var2)-1):
        var3=var2[1].split('_')
        lis.append((var3[1],var3[2]))
        dictionary_2[int(var2[0])] = lis

# %%
file=open("Term_ind.txt",encoding="utf8").read()
file2=file.split("\n")
dictionary_1={}
for i in range(len(file2)-1):
    var1=file2[i].split('_')
    dictionary_1[var1[1]]=var1[0]
dictionary_1
# Out:
# {'ملک': '0',
#  'امان': '1',
#  'صورت': '2',
#  'کنٹرول': '3',
#  ':': '4',
#  'فواد': '5',
#  'چوہدری': '6',
#  'اسلام': '7',
#  'آباد': '8',
#  'وزیراطلاعات': '9',
#  'کہنا': '10',
#  'ہے،': '11',
#  'ریاست': '12',
#  'صبر': '13',
#  'کمزوری': '14',
#  'سمجھا': '15',
#  'جائے۔': '16',
#  'خیالات': '17',
#  'اظہار': '18',
#  'سماجی': '19',
#  'رابطے': '20',
#  'ویب': '21',
#  'سائٹ': '22',
#  'ٹوئٹر': '23',
#  'جاری': '24',
#  'کردہ': '25',
#  'بیان': '26',
#  'کیا،': '27',
#  'آئین': '28',
#  'قانون': '29',
#  'مکمل': '30',
#  'عملداری': '31',
#  'عوام': '32',
#  'مفاد': '33',
#  'ہے۔': '34',
#  'فرض': '35',
#  'پورا': '36',
#  'گے،': '37',
#  'وزیر': '38',
#  'اعظم': '39',
#  'لمحہ': '40',
#  'باخبر': '41',
#  'جارہا': '42',
#  'مزید': '43',
#  'چین': '44',
#  'اہم': '45',
#  'دورے': '46',
#  'سبوتاژ': '47',
#  'کوشش': '48',
#  'ناکام': '49',
#  'ہوگی۔': '50',
#  'خوش': '51',
#  'گمانی': '52',
#  'کمزورہے،': '53',
#  'اپوزیشن': '54',
#  'ادارے': '55',
#  'حکومت': '56',
# ...

# %%
def read_func_1(term):
    
    var1= dictionary_1.get(term)
    print(var1)
    var2=dictionary_2.get(int(var1))
    for p in dictionary_2.get(int(var1)):
        print("Listing for term:", term)
        print("TERMID:", var1)
        print("Number of documents containing term:", str(p[1]))
        print("Term frequency in corpus:", str(p[0]))

# %%
read_func_1("امان")
# Out:
# 1
# Listing for term: امان
# TERMID: 1
# Number of documents containing term: 109
# Term frequency in corpus: 154

# %%
h=open(r"C:\Users\srida\Term_Index.txt")

# %%
def read_func_3(Doc,term):
    
    D=dictionary_3.get(Doc)
    var1=dictionary_2.get(term)
    b=dic4.get(int(var1))
    arr=[]
    arr2[]
    for i in dic4.get(int(var1)):
        print(i[0])
        arr.append(int(i[0]))
    for j in arr:
        f.seek(j)
        k=f.readline()
        var1=k.split('\t')
        arr.append(var1)
            
    print("Inverted list for term:",term+"\n"+"In document", Doc+"\n"+"TERMID:", term+"\n"+"DOCID:", D+"\n"+
          "Term frequency in document:", len(arr2)+"\n"+"Positions:", arr2)

# %%
read_func_3( '1.txt',"ملک")
